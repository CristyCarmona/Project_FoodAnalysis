# %% [markdown]
# ## Proyecto 2

# %%
import pandas as pd

# %%
food_csv="food.csv"

# %%
food_df= pd.read_csv(food_csv)

# %%
food_df.head()
# Out:
#      Category               Description  Nutrient Data Bank Number  \
# 0      BUTTER          BUTTER,WITH SALT                       1001
# 1      BUTTER  BUTTER,WHIPPED,WITH SALT                       1002
# 2  BUTTER OIL      BUTTER OIL,ANHYDROUS                       1003
# 3      CHEESE               CHEESE,BLUE                       1004
# 4      CHEESE              CHEESE,BRICK                       1005
#
#    Data.Alpha Carotene  Data.Ash  Data.Beta Carotene  Data.Beta Cryptoxanthin  \
# 0                    0      2.11                 158                        0
# 1                    0      2.11                 158                        0
# 2                    0      0.00                 193                        0
# 3                    0      5.11                  74                        0
# 4                    0      3.18                  76                        0
#
#    Data.Carbohydrate  Data.Cholesterol  Data.Choline  ...  \
# ...

# %%
#removal of columns that we won't use from the first csv
food_analysis_df= food_df[['Category', 'Description','Data.Carbohydrate', 'Data.Cholesterol', 'Data.Fiber', 'Data.Kilocalories', 'Data.Protein', 'Data.Sugar Total', 'Data.Water', 'Data.Fat.Monosaturated Fat', 'Data.Fat.Polysaturated Fat', 'Data.Fat.Saturated Fat', 'Data.Fat.Total Lipid', 'Data.Major Minerals.Copper', 'Data.Major Minerals.Iron', 'Data.Major Minerals.Magnesium', 'Data.Major Minerals.Phosphorus','Data.Major Minerals.Potassium', 'Data.Major Minerals.Sodium', 'Data.Major Minerals.Zinc', 'Data.Vitamins.Vitamin A','Data.Vitamins.Vitamin B12', 'Data.Vitamins.Vitamin B6', 'Data.Vitamins.Vitamin C', 'Data.Vitamins.Vitamin E', 'Data.Vitamins.Vitamin K']]
food_analysis_df.head()
# Out:
#      Category               Description  Nutrient Data Bank Number  \
# 0      BUTTER          BUTTER,WITH SALT                       1001
# 1      BUTTER  BUTTER,WHIPPED,WITH SALT                       1002
# 2  BUTTER OIL      BUTTER OIL,ANHYDROUS                       1003
# 3      CHEESE               CHEESE,BLUE                       1004
# 4      CHEESE              CHEESE,BRICK                       1005
#
#    Data.Carbohydrate  Data.Cholesterol  Data.Fiber  Data.Kilocalories  \
# 0               0.06               215         0.0                717
# 1               0.06               219         0.0                717
# 2               0.00               256         0.0                876
# 3               2.34                75         0.0                353
# 4               2.79                94         0.0                371
#
#    Data.Protein  Data.Sugar Total  Data.Water  ...  \
# 0          0.85              0.06       15.87  ...
# ...

# %%
#locate a food by its written description
food_analysis_df.loc[food_analysis_df['Description'] == 'BUTTER,WITH SALT']
# Out:
#   Category       Description  Nutrient Data Bank Number  Data.Carbohydrate  \
# 0   BUTTER  BUTTER,WITH SALT                       1001               0.06
#
#    Data.Cholesterol  Data.Fiber  Data.Kilocalories  Data.Protein  \
# 0               215         0.0                717          0.85
#
#    Data.Sugar Total  Data.Water  ...  Data.Major Minerals.Phosphorus  \
# 0              0.06       15.87  ...                              24
#
#    Data.Major Minerals.Potassium  Data.Major Minerals.Sodium  \
# 0                             24                         576
#
#    Data.Major Minerals.Zinc  Data.Vitamins.Vitamin A  \
# 0                      0.09                    0.684
#
#    Data.Vitamins.Vitamin B12  Data.Vitamins.Vitamin B6  \
# 0                    0.00017                     0.003
#
#    Data.Vitamins.Vitamin C  Data.Vitamins.Vitamin E  Data.Vitamins.Vitamin K
# 0                      0.0                     2.32                    0.007
#
# [1 rows x 27 columns]

# %%
#function to obtain an array of the categories
import pandas as pd
def obtener_categorias():
    food_csv="food.csv"
    food_df= pd.read_csv(food_csv)
    food_analysis_df= food_df[['Category', 'Description', 'Nutrient Data Bank Number','Data.Carbohydrate', 'Data.Cholesterol', 'Data.Fiber', 'Data.Kilocalories', 'Data.Protein', 'Data.Sugar Total', 'Data.Water', 'Data.Fat.Monosaturated Fat', 'Data.Fat.Polysaturated Fat', 'Data.Fat.Saturated Fat', 'Data.Fat.Total Lipid', 'Data.Major Minerals.Copper', 'Data.Major Minerals.Iron', 'Data.Major Minerals.Magnesium', 'Data.Major Minerals.Phosphorus','Data.Major Minerals.Potassium', 'Data.Major Minerals.Sodium', 'Data.Major Minerals.Zinc', 'Data.Vitamins.Vitamin A','Data.Vitamins.Vitamin B12', 'Data.Vitamins.Vitamin B6', 'Data.Vitamins.Vitamin C', 'Data.Vitamins.Vitamin E', 'Data.Vitamins.Vitamin K']]
    x=food_analysis_df['Category'].unique()
    return x

# %%
#arreglo con categorias únicas
categorias=obtener_categorias()
print(categorias)
# Out:
# ['BUTTER' 'BUTTER OIL' 'CHEESE' ... 'FROG LEGS' 'SNAIL' 'TURTLE']

# %%
import pandas as pd
def descripcion(categoria):
    food_csv="food.csv"
    food_df= pd.read_csv(food_csv)
    food_analysis_df= food_df[['Category', 'Description', 'Nutrient Data Bank Number','Data.Carbohydrate', 'Data.Cholesterol', 'Data.Fiber', 'Data.Kilocalories', 'Data.Protein', 'Data.Sugar Total', 'Data.Water', 'Data.Fat.Monosaturated Fat', 'Data.Fat.Polysaturated Fat', 'Data.Fat.Saturated Fat', 'Data.Fat.Total Lipid', 'Data.Major Minerals.Copper', 'Data.Major Minerals.Iron', 'Data.Major Minerals.Magnesium', 'Data.Major Minerals.Phosphorus','Data.Major Minerals.Potassium', 'Data.Major Minerals.Sodium', 'Data.Major Minerals.Zinc', 'Data.Vitamins.Vitamin A','Data.Vitamins.Vitamin B12', 'Data.Vitamins.Vitamin B6', 'Data.Vitamins.Vitamin C', 'Data.Vitamins.Vitamin E', 'Data.Vitamins.Vitamin K']]
    x=food_analysis_df.loc[food_analysis_df['Category'] == categoria]['Description']
    return x

# %%
descripciones=descripcion('BUTTER')
print(descripciones.values)
# Out:
# ['BUTTER,WITH SALT' 'BUTTER,WHIPPED,WITH SALT' 'BUTTER,WITHOUT SALT'
#  'BUTTER,LT,STK,W/SALT' 'BUTTER,LT,STK,WO/SALT']

# %%
import pandas as pd
def food(categoria, descripcion):
    food_csv="food.csv"
    food_df= pd.read_csv(food_csv)
    food_analysis_df= food_df[['Category', 'Description', 'Nutrient Data Bank Number','Data.Carbohydrate', 'Data.Cholesterol', 'Data.Fiber', 'Data.Kilocalories', 'Data.Protein', 'Data.Sugar Total', 'Data.Water', 'Data.Fat.Monosaturated Fat', 'Data.Fat.Polysaturated Fat', 'Data.Fat.Saturated Fat', 'Data.Fat.Total Lipid', 'Data.Major Minerals.Copper', 'Data.Major Minerals.Iron', 'Data.Major Minerals.Magnesium', 'Data.Major Minerals.Phosphorus','Data.Major Minerals.Potassium', 'Data.Major Minerals.Sodium', 'Data.Major Minerals.Zinc', 'Data.Vitamins.Vitamin A','Data.Vitamins.Vitamin B12', 'Data.Vitamins.Vitamin B6', 'Data.Vitamins.Vitamin C', 'Data.Vitamins.Vitamin E', 'Data.Vitamins.Vitamin K']]
    x=food_analysis_df.loc[(food_analysis_df['Category'] == categoria) & (food_analysis_df['Description'] == descripcion)]
    return x

# %%
#reemplazar Data.Protein por nombre de otra columna para realizar busqueda

f=food('BUTTER', 'BUTTER,WITH SALT')
print(f)
print('')
print(f['Data.Protein'].values[0])
# Out:
#   Category       Description  Nutrient Data Bank Number  Data.Carbohydrate  \
# 0   BUTTER  BUTTER,WITH SALT                       1001               0.06
#
#    Data.Cholesterol  Data.Fiber  Data.Kilocalories  Data.Protein  \
# 0               215         0.0                717          0.85
#
#    Data.Sugar Total  Data.Water  ...  Data.Major Minerals.Phosphorus  \
# 0              0.06       15.87  ...                              24
#
#    Data.Major Minerals.Potassium  Data.Major Minerals.Sodium  \
# 0                             24                         576
#
#    Data.Major Minerals.Zinc  Data.Vitamins.Vitamin A  \
# 0                      0.09                    0.684
#
#    Data.Vitamins.Vitamin B12  Data.Vitamins.Vitamin B6  \
# 0                    0.00017                     0.003
#
#    Data.Vitamins.Vitamin C  Data.Vitamins.Vitamin E  Data.Vitamins.Vitamin K
# 0                      0.0                     2.32                    0.007
#
# [1 rows x 27 columns]
#
# ...
